# %%
import pandas as pd
import os

# %%
# python program to access sub directories using os library?

# %%
def row2head():
        global ind_df
        new_header = ind_df.iloc[0]  # grab the first row for the header"
        ind_df = ind_df[1:]  # take the data less the header row"
        ind_df.columns = new_header  # set the header row as theind_df header"

ind_df_consolidate = pd.DataFrame()



    # loop all master data files
ind_df = pd.read_csv('L14220TG1978PLC002390_master_data.csv')
ind_df = ind_df.T
ind_df.index=[0,1]
row2head()
ind_df_consolidate = pd.concat([ind_df_consolidate, ind_df])
ind_df_consolidate
# Out:
# 0                    CIN                  Company / LLP Name       ROC Code  \
# 1  L14220TG1978PLC002390  SURYAVANSHI SPINNING MILLS LIMITED  RoC-Hyderabad
#
# 0 Registration Number           Company Category Company SubCategory  \
# 1              002390  Company limited by Shares    Non-govt company
#
# 0 Class of Company  Authorised Capital(Rs) Paid up Capital(Rs)  \
# 1            Public              352500000            49085760
#
# 0 Number of Members(Applicable in case of company without Share Capital)  ...  \
# 1                                                  0                      ...
#
# 0  Immovable property or any interest therein; Book debts; Floating charge; Movable property (not being pledge); Personal Guarantees  \
# 1                                         28/03/2015
#
# 0         NaN  NaN Directors/Signatory Details     DIN/PAN  0000041892  \
# 1  20/07/2022  NaN                         NaN  Begin date  30/05/2012
#
# ...

# %%
# os.listdir(os.getcwd())
# master_df=pd.DataFrame()
# fi=os.listdir(os.getcwd())                                                    
# for files in fi:
#     if files.endswith('.csv'):
#         master_df=master_df.append(pd.read_csv(files))



# master_df
root_dir= "../ROC_HYD/"

for dir_path, dir_names, file_names in os.walk(root_dir):
    for file_name in file_names:
        file_path = os.path.join(dir_path, file_name)
        if (file_name.endswith('master_data.csv')):
             print(file_name)
             df=pd.read_csv(file_name)
             print(df)

        else:
            continue
        

df
# Out:
# L14220TG1978PLC002390_master_data.csv
#                                   Company Master Data  \
# 0                                                 CIN
# 1                                  Company / LLP Name
# 2                                            ROC Code
# 3                                 Registration Number
# 4                                    Company Category
# 5                                 Company SubCategory
# 6                                   Class of Company
# 7                              Authorised Capital(Rs)
# 8                                 Paid up Capital(Rs)
# 9   Number of Members(Applicable in case of compan...
# 10                              Date of Incorporation
# 11                                 Registered Address
# 12                                           Email Id
# 13                              Whether Listed or not
# 14                                   Date of last AGM
# 15                              Date of Balance Sheet
# ...

# %%
for dirpath, dirnames, filenames in os.walk(root_dir):
    for filename in filenames:
        
        if filename.endswith('master_data.csv'):
            # Create the full path to the file
            filepath = os.path.join(dirpath, filename)
            # Read the data from the file
            ind_df = pd.read_csv(filepath)
            ind_df=ind_df.T
            row2head()
            # print(ind_df)
            # ind_df.set_index('CIN')

            # print(ind_df)
            
            # Append the data to the DataFrame
            
            ind_df_consolidate = pd.concat([ind_df_consolidate, ind_df])
            
            print('problem')
# Print the concatenated data
# print(all_data)
# Out:
# problem
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[8], line 18
#      10             row2head()
#      11             # print(ind_df)
#      12             # ind_df.set_index('CIN')
#      13
#      14             # print(ind_df)
#      15
#      16             # Append the data to the DataFrame
# ---> 18             ind_df_consolidate = pd.concat([ind_df_consolidate, ind_df])
#      20             print('problem')
#      21 # Print the concatenated data
#      22 # print(all_data)
#
# File c:\Program Files\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# ...

# %%
import os
import pandas as pd

# Define the root directory
# root_dir = '/path/to/root/directory

# Define an empty DataFrame to store the data
all_data = pd.DataFrame()

# Use os.walk() to recursively traverse all subdirectories and files
for dirpath, dirnames, filenames in os.walk(root_dir):
    for filename in filenames:
        # Check if the file has the desired extension (e.g., .csv)
        if filename.endswith('master_data.csv'):
            # Create the full path to the file
            filepath = os.path.join(dirpath, filename)
            # Read the data from the file
            ind_df = pd.read_csv(filepath)
            ind_df = ind_df.T
            row2head()
            # print(file_name)
            # ind_df_consolidate = pd.concat([ind_df_consolidate, ind_df])
           
            # Append the data to the DataFrame
            # all_data = pd.concat([all_data, data], ignore_index=True)

# Print the concatenated data
# print(all_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 18
#      16 filepath = os.path.join(dirpath, filename)
#      17 # Read the data from the file
# ---> 18 ind_df = pd.read_csv(filepath)
#      19 ind_df = ind_df.T
#      20 row2head()
#
# File c:\Program Files\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# os.access('')
# os.path.exists('ROC_HYD')
from pathlib import Path

all_lines = []
path = Path('cin=L01113TG1994PLC018750/')
for file in path.iterdir():
    with file.open() as f:
        all_lines.append(f.read())
print(all_lines)
